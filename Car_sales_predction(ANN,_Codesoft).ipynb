# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171
# Trainable params: 171
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 42ms/step - loss: 0.0868 - mean_absolute_error: 0.2477 - val_loss: 0.0688 - val_mean_absolute_error: 0.2105
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0414 - mean_absolute_error: 0.1627 - val_loss: 0.0403 - val_mean_absolute_error: 0.1622
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0318 - mean_absolute_error: 0.1438 - val_loss: 0.0350 - val_mean_absolute_error: 0.1544
# Epoch 4/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0297 - mean_absolute_error: 0.1380 - val_loss: 0.0316 - val_mean_absolute_error: 0.1454
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0259 - mean_absolute_error: 0.1269 - val_loss: 0.0290 - val_mean_absolute_error: 0.1362
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0232 - mean_absolute_error: 0.1195 - val_loss: 0.0273 - val_mean_absolute_error: 0.1305
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0212 - mean_absolute_error: 0.1139 - val_loss: 0.0243 - val_mean_absolute_error: 0.1235
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0193 - mean_absolute_error: 0.1083 - val_loss: 0.0217 - val_mean_absolute_error: 0.1172
# Epoch 9/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0175 - mean_absolute_error: 0.1031 - val_loss: 0.0195 - val_mean_absolute_error: 0.1113
# Epoch 10/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0161 - mean_absolute_error: 0.0984 - val_loss: 0.0175 - val_mean_absolute_error: 0.1060
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0148 - mean_absolute_error: 0.0943 - val_loss: 0.0161 - val_mean_absolute_error: 0.1012
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0134 - mean_absolute_error: 0.0899 - val_loss: 0.0144 - val_mean_absolute_error: 0.0963
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0124 - mean_absolute_error: 0.0859 - val_loss: 0.0129 - val_mean_absolute_error: 0.0920
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0113 - mean_absolute_error: 0.0818 - val_loss: 0.0119 - val_mean_absolute_error: 0.0880
# Epoch 15/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0104 - mean_absolute_error: 0.0784 - val_loss: 0.0107 - val_mean_absolute_error: 0.0839
# Epoch 16/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0743 - val_loss: 0.0095 - val_mean_absolute_error: 0.0802
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0085 - mean_absolute_error: 0.0705 - val_loss: 0.0087 - val_mean_absolute_error: 0.0764
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0671 - val_loss: 0.0078 - val_mean_absolute_error: 0.0727
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0635 - val_loss: 0.0070 - val_mean_absolute_error: 0.0689
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0062 - mean_absolute_error: 0.0600 - val_loss: 0.0062 - val_mean_absolute_error: 0.0650
# Epoch 21/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0055 - mean_absolute_error: 0.0568 - val_loss: 0.0055 - val_mean_absolute_error: 0.0614
# Epoch 22/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0536 - val_loss: 0.0050 - val_mean_absolute_error: 0.0578
# Epoch 23/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0044 - mean_absolute_error: 0.0507 - val_loss: 0.0044 - val_mean_absolute_error: 0.0539
# Epoch 24/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 0.0039 - val_mean_absolute_error: 0.0507
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0035 - val_mean_absolute_error: 0.0476
# Epoch 26/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0031 - mean_absolute_error: 0.0424 - val_loss: 0.0032 - val_mean_absolute_error: 0.0448
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 29/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0021 - val_mean_absolute_error: 0.0363
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0331 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 32/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 33/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 35/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.7377e-04 - mean_absolute_error: 0.0237 - val_loss: 9.0153e-04 - val_mean_absolute_error: 0.0233
# Epoch 36/50
# 10/10 [==============================] - 0s 8ms/step - loss: 8.5387e-04 - mean_absolute_error: 0.0219 - val_loss: 7.5327e-04 - val_mean_absolute_error: 0.0214
# Epoch 37/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.5891e-04 - mean_absolute_error: 0.0207 - val_loss: 6.6266e-04 - val_mean_absolute_error: 0.0201
# Epoch 38/50
# 10/10 [==============================] - 0s 8ms/step - loss: 6.3355e-04 - mean_absolute_error: 0.0187 - val_loss: 5.4396e-04 - val_mean_absolute_error: 0.0182
# Epoch 39/50
# 10/10 [==============================] - 0s 7ms/step - loss: 5.4993e-04 - mean_absolute_error: 0.0174 - val_loss: 4.7787e-04 - val_mean_absolute_error: 0.0170
# Epoch 40/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.7411e-04 - mean_absolute_error: 0.0159 - val_loss: 3.9891e-04 - val_mean_absolute_error: 0.0154
# Epoch 41/50
# 10/10 [==============================] - 0s 5ms/step - loss: 4.0360e-04 - mean_absolute_error: 0.0145 - val_loss: 3.4266e-04 - val_mean_absolute_error: 0.0142
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4642e-04 - mean_absolute_error: 0.0131 - val_loss: 2.7466e-04 - val_mean_absolute_error: 0.0127
# Epoch 43/50
# 10/10 [==============================] - 0s 5ms/step - loss: 2.9933e-04 - mean_absolute_error: 0.0119 - val_loss: 2.3024e-04 - val_mean_absolute_error: 0.0116
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.5208e-04 - mean_absolute_error: 0.0107 - val_loss: 1.8894e-04 - val_mean_absolute_error: 0.0105
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.1874e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5842e-04 - val_mean_absolute_error: 0.0097
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8927e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3139e-04 - val_mean_absolute_error: 0.0088
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.6309e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0833e-04 - val_mean_absolute_error: 0.0079
# Epoch 48/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3952e-04 - mean_absolute_error: 0.0072 - val_loss: 9.9758e-05 - val_mean_absolute_error: 0.0077
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2552e-04 - mean_absolute_error: 0.0067 - val_loss: 7.5897e-05 - val_mean_absolute_error: 0.0066
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0905e-04 - mean_absolute_error: 0.0060 - val_loss: 6.4171e-05 - val_mean_absolute_error: 0.0060

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.995590898246591
